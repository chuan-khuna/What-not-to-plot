# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from utils.data_generators import generate_data
from utils.notplot import plot_split_pie
from utils.utils import *

# %%
colors = load_yaml('./data/ft-colors.yml')

# %%
def normal(n):
    mu = 10
    s = 2
    data = np.random.randn(n)
    
    return (s*data)+mu

def uniform(n):
    data = np.random.randint(1, n, n)
    return data

# %%
normal(8)
# Out:
# array([11.80436872, 11.98810236,  9.33263353, 11.18162247, 10.48016502,
#        11.53549416,  8.51118358,  8.41310605])

# %%
df = generate_data(16, normal, "./data/pie/normal")

# %%
fig = plt.figure(figsize=(7, 5), dpi=150)
plt.pie(df['value'], labels=df['long_name'], colors=['#355778'], wedgeprops={'linewidth': 1, 'edgecolor': 'white'})
plt.show()

# %%
sns.barplot(df.sort_values('value', ascending=False), x='value', y='long_name', color='#355778')
# Out:
# <AxesSubplot:xlabel='value', ylabel='long_name'>

# %%
plot_split_pie(df, ax_names='long_name')
